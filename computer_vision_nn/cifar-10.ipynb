# %%
from torchvision import datasets

# %%
import os

# %%
data_path = "/Users/soanni/PROJECTS/pytorch-2e/data-unversioned/p1ch07/"
os.makedirs(data_path, exist_ok=True)
# training dataset
cifar10_train = datasets.CIFAR10(data_path, train=True, download=True)
#validation dataset
cifar10_val = datasets.CIFAR10(data_path, train=False, download=True)
# Out:
# /opt/anaconda3/envs/pytorch-2e-py311/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %%
# method-resolution order
# base class is a torch.utils.data.dataset.Dataset which is a heart of all torchvision datasets
# torch.utils.data.dataset.Dataset has __len__ and __getitem__ methods.
# The former should return the number of items in the dataset, 
# and the latter should return the item, consisting of a sample and its corresponding label (an integer index).
# So it doesn’t necessarily hold the data, but it provides uniform access to it through __len__ and __getitem__
# PIL (Python Imaging Library, the PIL package) 
type(cifar10_train).__mro__
# Out:
# (torchvision.datasets.cifar.CIFAR10,
#  torchvision.datasets.vision.VisionDataset,
#  torch.utils.data.dataset.Dataset,
#  typing.Generic,
#  object)

# %%
len(cifar10_train)
# Out:
# 50000

# %%
# get the image and label
img, label = cifar10_train[-1]

# %%
img, label
# Out:
# (<PIL.Image.Image image mode=RGB size=32x32>, 1)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### transhorm an image to a tensor

# %%
from torchvision import transforms
